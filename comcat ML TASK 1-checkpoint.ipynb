# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")

# %%
data=pd.read_csv('task1.csv')

# %%
data.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %% [markdown]
# Which complaint types are maximum i.e., around internet, network issues, or across any other domains.
# - Create a new categorical variable with value as Open and Closed. Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed.
# - Provide state wise status of complaints in a stacked bar chart. Use the categorized variable from Q3. Provide insights on:

# %%
data["Status"].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
ser1 = data['Status']
ser1
# Out:
# 0       Closed
# 1       Closed
# 2       Closed
# 3         Open
# 4       Solved
#          ...
# 2219    Closed
# 2220    Solved
# 2221    Solved
# 2222    Solved
# 2223      Open
# Name: Status, Length: 2224, dtype: object

# %%
ser2 = ser1.replace({"Solved":"Closed",'Pending':'Open'})

# %%
df3 = pd.DataFrame(ser2)
df3

df3 = df3.rename(columns = {"Status":"New"})
df3
# Out:
#          New
# 0     Closed
# 1     Closed
# 2     Closed
# 3       Open
# 4     Closed
# ...      ...
# 2219  Closed
# 2220  Closed
# 2221  Closed
# 2222  Closed
# 2223    Open
#
# [2224 rows x 1 columns]

# %%
data = pd.concat([data,df3],axis = 1)
data.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone     New
# ...

# %%
d = data['State'].value_counts()

df5 = pd.DataFrame(d)
df5


df5 = df5.rename(columns = {"State":"frequency"})
df5

df5["State"] = df5.index
df5

df5.reset_index(drop=True)
# Out:
#     frequency                 State
# 0         288               Georgia
# 1         240               Florida
# 2         220            California
# 3         164              Illinois
# 4         143             Tennessee
# 5         130          Pennsylvania
# 6         115              Michigan
# 7          98            Washington
# 8          80              Colorado
# 9          78              Maryland
# 10         75            New Jersey
# 11         71                 Texas
# 12         61         Massachusetts
# 13         60              Virginia
# 14         59               Indiana
# 15         49                Oregon
# 16         39           Mississippi
# 17         33             Minnesota
# 18         26               Alabama
# 19         22                  Utah
# 20         20               Arizona
# 21         18        South Carolina
# 22         16  District Of Columbia
# 23         15            New Mexico
# 24         13             Louisiana
# ...

# %% [markdown]
# georgia has the highest number of complaints

# %% [markdown]
# Q. Which state has the highest percentage of unresolved complaints

# %%
p = data[data['New']=='Open']
p

#r = p["State"].value_counts()
#r
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 6      361148      Throttling service and unreasonable data caps  24-06-15
# 9      371214  Comcast Raising Prices and Not Being Available...  28-06-15
# 12     339282  Comcast Violating Open Internet Rules by Block...  13-06-15
# 15     370137                                 Internet complaint  27-06-15
# ...       ...                                                ...       ...
# 2196   339481             Terrible internet service from Comcast  13-06-15
# 2202   305166                                    comcst data cap  24-05-15
# 2208   374570                                        comcast cap  30-06-15
# 2218   338192    Speed throttling, speeds not at promised output  06-12-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %% [markdown]
# - Provide the percentage of complaints resolved till date, which were received through the Internet and customer care calls.

# %%
q = data[data['New']=='Closed']
q
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# 5      338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# ...       ...                                                ...       ...
# 2217   254488                     problems with internet service  24-04-15
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
#
#      Date_month_year         Time        Received Via        City  \
# ...

# %%
s=q[q["Received Via"].isin(["Internet","Customer Care Call"])]
s = q["Received Via"].value_counts()
s
# Out:
# Customer Care Call    864
# Internet              843
# Name: Received Via, dtype: int64
