# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")

# %%
data=pd.read_csv('task1.csv')

# %%
data.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %% [markdown]
# Which complaint types are maximum i.e., around internet, network issues, or across any other domains.
# - Create a new categorical variable with value as Open and Closed. Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed.
# - Provide state wise status of complaints in a stacked bar chart. Use the categorized variable from Q3. Provide insights on:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %%
data['Date_month_year']= pd.to_datetime(data['Date_month_year'])
data['Date_month_year']
# Out:
# 0      2015-04-22
# 1      2015-08-04
# 2      2015-04-18
# 3      2015-07-05
# 4      2015-05-26
#           ...
# 2219   2015-02-04
# 2220   2015-02-06
# 2221   2015-09-06
# 2222   2015-06-23
# 2223   2015-06-24
# Name: Date_month_year, Length: 2224, dtype: datetime64[ns]

# %%
data['Date_month_year'].dt.month
# Out:
# 0       4
# 1       8
# 2       4
# 3       7
# 4       5
#        ..
# 2219    2
# 2220    2
# 2221    9
# 2222    6
# 2223    6
# Name: Date_month_year, Length: 2224, dtype: int64

# %%
data['Date_month_year'].dt.day
# Out:
# 0       22
# 1        4
# 2       18
# 3        5
# 4       26
#         ..
# 2219     4
# 2220     6
# 2221     6
# 2222    23
# 2223    24
# Name: Date_month_year, Length: 2224, dtype: int64

# %%
data['month']=data['Date_month_year'].dt.month
data['day']=data['Date_month_year'].dt.day

# %%
data['month'].unique()
# Out:
# array([ 4,  8,  7,  5, 12,  6,  1, 11,  2,  9,  3, 10], dtype=int64)

# %%
data.sort_values("month")
# Out:
#      Ticket #                             Customer Complaint      Date  \
# 1951   316650                              Interrnet Service  06-01-15
# 1415   212595                                    overcharged  04-01-15
# 364    316295                           Comcast poor service  06-01-15
# 1410   212228    Comcast Lied About Pricing And Installation  04-01-15
# 512    317983           Comcast Internet Service Bad Quality  06-01-15
# ...       ...                                            ...       ...
# 1161   231374        Fraudulent Billing practices by Comcast  04-12-15
# 2076   336982                               Comcast monopoly  06-12-15
# 1157   231375               Comcast Unfair Billing Practices  04-12-15
# 1602   337691  Comcast Billing (primary) Service (secondary)  06-12-15
# 1363   338510                                        Comcast  06-12-15
#
#      Date_month_year         Time        Received Via          City  \
# ...

# %%
x = data['month'].value_counts()
print(x)
# Out:
# 6     1046
# 4      375
# 5      317
# 8       67
# 12      65
# 2       59
# 9       55
# 1       55
# 10      53
# 7       49
# 3       45
# 11      38
# Name: month, dtype: int64

# %%
df = pd.DataFrame(x)
df

df = df.rename(columns = {"month":"frequency"})
df

df["month"] = df.index
df
# Out:
#     frequency  month
# 6        1046      6
# 4         375      4
# 5         317      5
# 8          67      8
# 12         65     12
# 2          59      2
# 9          55      9
# 1          55      1
# 10         53     10
# 7          49      7
# 3          45      3
# 11         38     11

# %%
df = df.sort_values("month")

# %%
sns.barplot(x="month", y="frequency",data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='frequency'>

# %%
data.sort_values("Date_month_year")
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 1160   211472                                      comcast cable  04-01-15
# 767    213355  Comcast is ignoring me now. They are making NO...  04-01-15
# 2143   213198                                 Fradulent Services  04-01-15
# 268    212818                                  Incorrect Billing  04-01-15
# 908    211904  Unable to get in touch with anyone that has th...  04-01-15
# ...       ...                                                ...       ...
# 34     337489                    Comcast not refunding my credit  06-12-15
# 1063   336690                                  Comcast Data Caps  06-12-15
# 465    336234                                  Unresolved Issues  06-12-15
# 1845   336532                  Billing & Customer Service Issues  06-12-15
# 2076   336982                                   Comcast monopoly  06-12-15
#
# ...

# %%
y = data["Date_month_year"].value_counts()
print(y)
# Out:
# 2015-06-24    218
# 2015-06-23    190
# 2015-06-25     98
# 2015-06-26     55
# 2015-06-30     53
#              ...
# 2015-05-17      7
# 2015-12-05      7
# 2015-05-04      6
# 2015-11-04      5
# 2015-03-05      5
# Name: Date_month_year, Length: 91, dtype: int64

# %%
df1 = pd.DataFrame(y)
df1

df1 = df1.rename(columns = {"Date_month_year":"frequency"})
df1

df1["Days"] = df1.index
df1


df1.reset_index(drop=True)
# Out:
#     frequency       Days
# 0         218 2015-06-24
# 1         190 2015-06-23
# 2          98 2015-06-25
# 3          55 2015-06-26
# 4          53 2015-06-30
# ..        ...        ...
# 86          7 2015-05-17
# 87          7 2015-12-05
# 88          6 2015-05-04
# 89          5 2015-11-04
# 90          5 2015-03-05
#
# [91 rows x 2 columns]

# %%
df1.sort_values("Days")
# Out:
#             frequency       Days
# 2015-01-04         18 2015-01-04
# 2015-01-05         12 2015-01-05
# 2015-01-06         25 2015-01-06
# 2015-02-04         27 2015-02-04
# 2015-02-05          7 2015-02-05
# ...               ...        ...
# 2015-11-05         12 2015-11-05
# 2015-11-06         21 2015-11-06
# 2015-12-04         15 2015-12-04
# 2015-12-05          7 2015-12-05
# 2015-12-06         43 2015-12-06
#
# [91 rows x 2 columns]

# %%
sns.lineplot(x="Days", y="frequency",data=df1)
# Out:
# <AxesSubplot:xlabel='Days', ylabel='frequency'>

# %% [markdown]
#  Provide a table with the frequency of complaint types.

# %%
a = data['Customer Complaint'].value_counts()
print(a)
# Out:
# Comcast                                                                     83
# Comcast Internet                                                            18
# Comcast Data Cap                                                            17
# comcast                                                                     13
# Comcast Billing                                                             11
#                                                                             ..
# Comcast e-mail issues                                                        1
# Comcast will not let me discuss my bill or service with a representative     1
# Internet out all the time but they have a monopoly                           1
# Comcast Monopoly in Calvert County, Maryland                                 1
# Comcast keeps changing bill and every time gives new reasons!!               1
# Name: Customer Complaint, Length: 1841, dtype: int64
